# %% [markdown]
# 교보문고 : page가 넘어가도 url 변화가 없음

# %%
import requests
from bs4 import BeautifulSoup

book_review = []
url = 'http://booklog.kyobobook.co.kr/blog/listSubMainReview.do'
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

#contents > div.list_wrap > div:nth-child(1) > div.title > a
#contents > div.list_wrap > div:nth-child(3) > p
#contents > div.list_wrap > div:nth-child(9) > p
#contents > div.list_wrap > div:nth-child(9) > p
#contents > div.list_wrap > div:nth-child(7) > p
pages = range(1,100)
for page in pages:
  src = '#contents > div.list_wrap > div:nth-of-type({})> p'.format(page)
  src2 = '#contents > div.list_wrap > div:nth-of-type({}) > div.title > a'.format(page)
  reviews = soup.select(src)
  names = soup.select(src2)
  book_review.extend([names,reviews])

book_review
# Out:
# [[<a class="entry_title" href="http://booklog.kyobobook.co.kr/friendlbs8/2343789">2022 에듀윌 공인중개사 2차 부동산세법  기출족보OX</a>],
#  [<p>          기본서+핵심요약집+단원별or회차별 기출문제집을 보았다면 고득점 합격을 위한~~과락 없는 합격을 위해 도움을 받을 수 있는 족집게 문제집 기출족보OX에 대해 알아보아요^€~                   ##문제 풀기전에 중요한 부분을 요약해서 정리되어있어요.      먼저 요약을 한번보구 기출 지문을 보면 한 페이지를 기준으로 한부분은 출제된 지문 그대로 정리되어있고 바로 옆쪽엔 바르게 고쳐진 지문이 비교되어 있...</p>],
#  [<a class="entry_title" href="http://booklog.kyobobook.co.kr/wave219/2343788">너는 어떤 사람이 되고 싶어?</a>],
#  [<p>    "선생님, 하고 싶은 일이 없어요."       "선생님, 커서 무엇이 되어야할지 모르겠어요."        아이들과 꿈에 대해 이야기 하다보면 언제나 나오는 아이들의 말. 사실 근본적으로 던지고 싶은 질문은 이 책의 제목과 같다.      "너는 어떤 사람이 되고 싶어?"       철학적인 이 질문에 대해 명쾌하게 답변하는 성인도 많지 않을 것이다. 또한 아직까지도 이를 찾아 헤매며 살아가는 어른아이들도 많다. 그만큼 어려운 질문...</p>],
#  [<a class="entry_title" href="http://booklog.kyobobook.co.kr/sacho75/2343787">달빛 천사 구미호</a>],
# ...

# %% [markdown]
# ---
# 네이버 블로그 검색: 서평 ERROR

# %%
##https://section.blog.naver.com/Search/Post.naver?pageNo=1&rangeType=ALL&orderBy=sim&keyword=%5B%EC%84%9C%ED%8F%89%5D
#content > section > div.area_list_search > div:nth-child(2) > div > div.info_post > div.desc
#content > section > div.area_list_search > div:nth-child(7) > div > div.info_post > div.desc
import requests
from bs4 import BeautifulSoup

rating_pages = []
pages = range(1, 10)
classes = range(1,7)
for page in pages:
    url = "https://section.blog.naver.com/Search/Post.naver?pageNo={}&rangeType=ALL&orderBy=sim&keyword=%5B서평%5D".format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    reviews = soup.find_all('.desc')
    print(reviews)

# %% [markdown]
#   for i in classes:
#       src = '#content > section > div.area_list_search > div:nth-child({}) > div > div.info_post > div.desc'.format(i)
#       reviews = soup.find(".desc")
#       print(reviews)
#       rating_pages.append(reviews)

# %% [markdown]
# ---
#
#
#
# ---
# 알라딘

# %%
pip install selenium

# %%
pip install webdriver-manager

# %%
import requests
from bs4 import BeautifulSoup
from selenium import webdriver
from webdriver_manager.chrome import ChromeDriverManager


# selenium에서 사용할 웹 드라이버 절대 경로 정보
chromedriver = r'C:\chromedriver_win32\chromedriver.exe'
# selenum의 webdriver에 앞서 설치한 chromedirver를 연동한다.
driver = webdriver.Chrome(r'C:\chromedriver_win32\chromedriver.exe')
# driver로 특정 페이지를 크롤링한다.

# %%
book_review = []
url = 'https://blog.aladin.co.kr/town/contents/review'
response = requests.get(url)
soup = BeautifulSoup(response.text,'html.parser')

#page_list_7 > table:nth-child(19) > tbody > tr > td:nth-child(3)
#page_list_7 > table:nth-child(3) > tbody > tr > td:nth-child(3)
pages = range(1,30)
tables = range(1,20)
for page in pages:
  for table in tables:
    src = '#page_list_{} > table:nth-of-type({}) > tbody > tr > td:nth-of-type(3)'.format(page,table)
    lists = soup.select(src)
    print(lists)

# %%
book_review
# Out:
# []

# %% [markdown]
# ---
#
#
#
# ---
#
# 신문사의 책 서평

# %%
import requests
from bs4 import BeautifulSoup
#main > div.story-feed > div > div:nth-child(1) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__sigline.\|.flex.flex--align-items-center.flex--wrap.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43 > div > div
#main > div.story-feed > div > div:nth-child(9) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__deck.\|.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43.text--overflow-ellipsis > span
#main > div.story-feed > div > div:nth-child(7) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__deck.\|.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43.text--overflow-ellipsis > span
#main > div.story-feed > div > div:nth-child(20) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__deck.\|.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43.text--overflow-ellipsis > span
#main > div.story-feed > div > div:nth-child(1) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__deck.\|.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43.text--overflow-ellipsis > span

book_review = []
pages = range(2,10)
div_lange = range(1,2)
for page in pages:
    url = "https://www.chosun.com/culture-life/book/?page={}".format(page)
    response = requests.get(url)
    soup = BeautifulSoup(response.text,'html.parser')
    for div in div_lange:
      src = '#main > div.story-feed > div > div:nth-of-type({}) > div > div > div > div.story-card.story-card--art-left.\|.flex.flex--wrap > div.story-card-block.story-card-right.\|.grid__col--sm-8.grid__col--md-8.grid__col--lg-8 > div.story-card-component.story-card__sigline.\|.flex.flex--align-items-center.flex--wrap.text--grey-60.font--primary.font--size-sm-14.font--size-md-14.text--line-height-1\.43 > div > div'.format(div)
      reviews = soup.select(src)
      print(reviews)
      book_review.append(reviews)
# Out:
# []
# []
# []
# []
# []
# []
# []
# []
