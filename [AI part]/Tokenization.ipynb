# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
#한글형태소 추출 라이브러리 설치
# !pip install KoNLPy
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting KoNLPy
#   Downloading konlpy-0.6.0-py2.py3-none-any.whl (19.4 MB)
#      |████████████████████████████████| 19.4 MB 4.3 MB/s
# Requirement already satisfied: numpy>=1.6 in /usr/local/lib/python3.7/dist-packages (from KoNLPy) (1.21.6)
# Requirement already satisfied: lxml>=4.1.0 in /usr/local/lib/python3.7/dist-packages (from KoNLPy) (4.2.6)
# Collecting JPype1>=0.7.0
#   Downloading JPype1-1.4.0-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (453 kB)
#      |████████████████████████████████| 453 kB 53.9 MB/s
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from JPype1>=0.7.0->KoNLPy) (4.1.1)
# Installing collected packages: JPype1, KoNLPy
# Successfully installed JPype1-1.4.0 KoNLPy-0.6.0

# %%
#모델 생성
from konlpy.tag import Komoran
komoran = Komoran()

# %%
import pandas as pd
import numpy as np

#영화 리뷰데이터 가져오기
reviews = pd.read_csv('/content/drive/MyDrive/movie_reviews_ver3.csv')
reviews
# Out:
#       Unnamed: 0  Unnamed: 0.1              titles  rates  \
# 0              0             0               미니언즈2     10
# 1              1             1  아이언 크로스: 노르망디 상륙작전     10
# 2              2             2             외계+인 1부     10
# 3              3             3                  메기      1
# 4              4             4              헤어질 결심     10
# ...          ...           ...                 ...    ...
# 9985        9985          9985               씨 비스트     10
# 9986        9986          9986              헤어질 결심     10
# 9987        9987          9987               그레이 맨     10
# 9988        9988          9988             외계+인 1부      8
# 9989        9989          9989             아무도 모른다     10
#
#                                                 reviews isit_domestic
# 0      미니언즈가 귀여운데 알아듣지 못하는 말을 해서 아쉽다. 어린이 조카가 무지 좋아한...         False
# 1                       전투 액션이 좋네요...스케일이 엄청납니다                 False
# 2               호불호가 있다고 했지만 재밌게 봤어요 2부도 기대 됩니다                  True
# 3        편하고 안전하게만 살아온 사람들만 공감할 수 있는 피해 망상의 영화…                  True
# 4                       많은 여운을 남긴 영화, 탕웨이 예뻐요!!                  True
# ...                                                 ...           ...
# 9985          뻔한스토리 전혀 없음 좋은 영화 아끼는 사람들과 함께 보세요                  True
# 9986                    기대 안 하고 봤는데 정말 재미있었습니다.                  True
# 9987   인생 액션영화 리스트에 저장했습니다.2시간 정말지루하지 않고 몰입감 있는 전개는 ...         False
# 9988  신선하고 재밌었어요. 평이 안 좋아서 기대를 안하고 가서 그랬는지 의외로 괜찮더라구...          True
# 9989   엄마가 첫째에게 돈을 남기고 갔을때 아들이 놀라지 않고 돈이 얼마인지 세는 장면이...          True
#
# [9990 rows x 6 columns]

# %%
#빈칸 지우기
review = []
for i in range(0, reviews.shape[0]):
  string = reviews.iloc[i,4]
  string = str(string) #형변환(float to string)
  string_2 = string.replace("  ","")
  print(string_2 + "end") #끝나는 것 재확인
  review.append(string_2)

# %%
lists = []

#토큰화 진행
for i in range(0, reviews.shape[0]):
  mini_1 = komoran.pos(review[i])
  mini_2 = []
  for k in mini_1:
    if k[1] in ('NNG', 'NNP', 'MM', 'MAG', 'IC', 'NF', 'NV'):
      mini_2.append(k[0])
    elif k[1] in ('VV', 'VA'):
      mini_2.append(k[0]+"다")
  print(mini_2)
  lists.append(mini_2)

#리스트에 저장 후 영화리뷰데이터에 별도 열로 추가
reviews['komoran'] = lists
# Out:
# ['미니언즈', '귀엽다', '알아듣다', '말', '하다', '아쉽다', '어린이', '조카', '무지', '좋아하다']
# ['전투', '액션', '좋다', '스케일', '엄청나다']
# ['불', '호가', '있다', '하다', '재밌다', '보다', '부도', '기대', '되다']
# ['편하다', '안전', '살아오다', '사람', '공감', '있다', '피해', '망상', '영화']
# ['많다', '여운', '남기다', '영화', '탕웨이', '예뻐', '요', '!!']
# ['최동훈', '더', '아쉽다', '맞다', '안', '아쉽다']
# ['안보', '신분', '없다', '바라다']
# ['범벅', '하다', '질', '흑인', '등장', '레온', '을', '호구', '찐따', '남성', '만들다', '영화']
# ['3년', '보다', '영화', '최고']
# ['최근', '보다', '영화', '최고']
# ['영화', '비행', '액션', '예능', '스토리', '완벽', '솔직히', '다크스타', '35', '이', '다', '영화']
# []
# ['진짜', '꼭', '영화관', '없어', '기전', '보다', '추천', '보다', '진짜', '여운', '결국', '포', '디', '엑스', '다시', '예', '매', '보다', '같이', '보다', '친구', '진짜', '강', '추하다', '역대', '급', '영화']
# ['과거', '현재', '미래', '김우빈', '오랜만', '영화', '보니', '너무', '좋다', '배우', '연기', '구멍', '없이', '최근', '보다', '어렵다', '이야기', '시간', '가다', '모르다', '보다']
# ['미', '해군', '왜', '눈물', '나다']
# ['매력', '세계관', '받히다', '스토리']
# ['이해도', '낮다', '이해', '힘들다', '생각', '길이', '길다', '집중', '좀', '힘들다', '하다', '내용', '이랑', '전체', '재밌다', '보다', '평점', '불', '많이', '갈리다', '걱정', '재밌다']
# ['이', '게', '영화', '냐', '이다', '영화']
# ['극장', '전체', '보다', '중간', '중간', '디테일', '아쉽다', '부분', '이정', '도면', '괜찮다', '뽑아내다', '생각']
# ['영화']
# ['창의', '스토리', '영상', '일품', '마블', '낫다']
# ['이', '영화', '정말', '좋다', '세월', '함께', '익다', '영화']
# ['극장', '보다', '추천', '집', '보다', '후회']
# ['겨우', '이', '돈', '내다', '영화', '보다', '되다', '정도', '스케일', '계속', '계속', '나오다', '호화', '캐스팅', '배우', '너무', '재밌다', '재밌다', '보다', '나오다', '평점', '보다', '놀라다', '알바', '있다', '정말', '재밌다', '보다', '최근', '보다', '매', '버', '릭', '범죄도시', '헤어지다', '결심', '다', '치다', '안', '들다', '같다']
# ['진짜', '액션', '좋다', '킬링타임', '상영', '관이', '왜', '이리', '없다', '아쉬움', '장혁', '버전', '아저씨', '라보', '되다']
# ['아니', '물리치다', '기미', '안', '보다', '과거', '회상', '나오다', '때', '빨리', '화장실', '가다', '가다', '영화', '끝나다', '아', '이렇다', '이렇다', '알다', '화장실', '안', '가다', '너무', '안', '좋아서', '조금', '놀라다', '개인', '액션', '잘', '보다', '아니', '가드', '어떡하다', '아', '놓다']
# ['액션', '한국', '맛', '그래픽', '규모', '헐리우드', '맛', '내용', '영상', '너무', '좋다', '휙휙', '바뀌다', '편집', '매력']
# []
# []
# ['꼬마', '살리다', '죽다', '영화']
# ['안', '보다', '후회합니다', '그냥', '보다']
# ['좀', '많이', '실험', '하다', '가볍다', '보다', '좋다']
# ['장면', '없다', '박찬욱', '미장센', '천재', '같다']
# ['고맙습니다', '완벽']
# ['타인', '이해', '위하다', '자신', '내면', '정면', '바라보다', '가뭄', '단비', '같다', '영화', '너무', '좋다', '정식', '수입', '좀', '제발']
# ['몰입', '높다', '정말', '집중', '잘', '보다', '있다', '이야기', '뻔하다', '잘', '풀다', '영화', '있다', '연우', '계속', '나아가다', '바라다']
# ['미결', '마음', '영원히', '기억', '안개', '끼다', '바다', '라스트', '정말', '아름답다', '눈물', '찔끔', '나다', '왠지', '모르다', '슬픔', '밀리다', '들다', '기억', '영화']
# ['간만', '영화', '다운', '영화', '보다']
# ['두', '보다', '두', '다', '너무', '좋다']
# ['나쁘다', '영화']
# ['음', '좀', '멀다', '아쉽다']
# ['현재', '최고', '재밌다', '볼', '영화인', '같다', '연출', '스토리', '넘', '재밌다']
# ['코로나', '시기', '좋다', '시간']
# ['그다지', '재미있다', '최동훈', '감독', '특유', '유머', '들어가다', '중간', '중간', '재미있다', '하다', '전체', '감독', '하다', '다', '섞다', '느낌', '러닝', '타임', '길다', '각종', '장르', '다', '섞이다', '있다', '시공간', '뒤죽박죽', '헷갈리다', '부모', '재밌다', '하다', '불', '호가', '갈리', '배우', '연기력', '좋아서', '그나마', '나다', '특히', '김우빈', '배우', '매력', '나오다', '같다', '좋다']
# ['타짜', '감독', '네', '긋다']
# ['너무', '좋다', '세번', '보다', '의향', '있다', '영화']
# ['도사', '물', '시간', '여행', '어느', '나라', '시도', '박', '한', '소재', '걱정', '처리', '한국', '영화', '수준', '세계', '수준', '올라오다', '느끼다', '다만', '스토리', '전개', '예상', '부분', '있다', '미리', '짐작', '부분', '영화', '내용', '상', '몰입', '도가', '저해', '요인', '부도', '기대']
# ['감독', '마블', '나오다', '어서']
# ['타짜', '감독', '맞다']
# ['아이들', '연기', '마음', '울리다']
# ['2년', '동안', '개봉', '연기', '게', '아쉽다', '차기', '작다', '언제', '나오다']
# ['꼭']
# ['노래', '있다', '최소', '평', '타']
# ['별다르다', '정보', '없이', '보다', '보다', '나다', '후', '진한', '감동', '느끼다', '이정은', '배우', '연기', '좋다', '감독', '연출']
# []
# []
# []
# []
# []
# ['절제', '절단', '영화']
# ['멋', '들다', '속편', '다시', '나오다', '있다']
# ['이토', '아오이', '배우', '차기', '작', '기대']
# ['흐지부지', '되다', '게', '왜', '이리', '많다']
# ['제목', '한글', '한자', '영어', '다', '있다', '영화']
# ['보다', '나서다', '더욱', '인상', '깊다']
# ['선녀']
# ['말', '아깝다', '영화']
# ['아이유', '팬', '이기다', '영화']
# ['너무', '뻔하다', '전개', '재미', '있다']
# ['기대', '만들다', '이상용', '감독']
# ['진짜', '왜', '시리즈', '인', '걸다']
# ['미니언즈', '너무', '귀여움']
# ['진짜', '진짜', '김우빈', '잘생기다', '재밌다', '진짜', '계속', '생각', '날', '영화인', '같다', '진짜', '다음', '나오다', '보다']
# ['전작', '너무', '강하다', '그렇다', '이번', '햄', '특유', '재치', '연기', '노래', '인상', '깊다', '!!']
# []
# ['매우', '정말', '재미있다', '보다', '앗다', '한번', '더', '보다', '의향', '잇다', '검색', '평점', '클릭', '하니', '평가', '기준', '하다', '계시다', '처음', '이렇다', '글', '남기다', '영화', '괘', '차다', '꽤', '만족', '정도', '그래픽', '이영화', '영상미', '잘', '어울리다', '조금', '꽤', '전투', '웃음', '포인트', '한국', '벗어나다', '영화로', '맘', '들다', '내놓다', '부끄럽다', '정도', '되다', '전', '생각', '가볍다', '즐기다', '좋다', '신중', '보다', '좋다', '절다', '매우', '칭찬', '한국', '장르', '발전', '생각', '감독', '형님', '정말', '잘', '판단', '태', '리', '배우', '매우', '이쁘다']
# ['마지막', '장편', '마치', '지옥', '내려가다', '장면', '압권']
# ['재밌다', '기대', '이상']
# ['마블', '말아먹다', '덕분', '유지']
# []
# []
# ['평점', '애', '예', '매', '취소', '땡기다', '그냥', '보다', '재미있다', '과거', '미래', '장면', '바뀌다', '잘', '이어지다', '이해력', '딸리다', '애', '평점', '낮다', '겁나다', '웃다', '염정아', '미치다', '웃다', '빨리', '보고싶다']
# ['생각', '그', '이상']
# ['벌써', '관람', '!!', '다시', '보다']
# ['솔', '찍히다', '후기', '다', '별로', '알다', '볼라', '망', '작', '나다', '재밌다', '사람', '다르다', '나다', '매우', '만족', '봄', '킬링타임', '좋다']
# ['레지던트', '이블', '시리즈', '다', '보다', '사람', '어이', '없다', '충격', '먹다', '어떻다', '카야', '쓰다', '이런', '망', '작']
# ['관람', '좋다', '기대다', '반', '걱정', '반', '보다', '재미', '있다', '보다', '장르', '액션', '무협', '판타지', '!!', '유머', '있다', '기다리다']
# ['클리셰', '잘', '풀어내다']
# ['액션', '연출', '미치다', '이', '정도', '급', '초능력자', '영화', '우리나라', '만들다', '줄이다']
# ['중국', '자본', '굴복', '미니언즈', '귀엽다', '중간', '미니언즈', '보다', '쿵', '푸다', '패다', '더 후', '속', '작', '보다']
# ['평생', '구설수', '시달리다', '능력', '있다', '왕', '결국', '좋다', '아비', '되다']
# ['왜', '이렇다', '욕', '먹다', '모르다', '우리나라', '관객', '영화', '수준', '생각', '이정', '도면']
# ['전', '너무', '재밌다', '왜', '평점', '낮다', '잘']
# ['다', '전개도', '별로', '하다', '별로', '기대', '안', '보다', '너무', '재밌다', '꼭', '보세', '요', '!!', '추천']
# ['단언', '크다', '영화', '바이블', '불리다', '손색없다', '명작', '액션', '감동', '레전드', '시작']
# []
# ---------------------------------------------------------------------------
# Exception                                 Traceback (most recent call last)
# Exception: Java Exception
#
# The above exception was the direct cause of the following exception:
#
# java.lang.NullPointerException            Traceback (most recent call last)
# <ipython-input-75-ce6a9ba3597f> in <module>()
#       3 #토큰화 진행
#       4 for i in range(0, reviews.shape[0]):
# ----> 5   mini_1 = komoran.pos(review[i])
#       6   mini_2 = []
#       7   for k in mini_1:
#
# /usr/local/lib/python3.7/dist-packages/konlpy/tag/_komoran.py in pos(self, phrase, flatten, join)
#      90             if not sentence:
#      91                 continue
# ---> 92             result = self.jki.analyze(sentence).getTokenList()
#      93             result = [(token.getMorph(), token.getPos()) for token in result]
#      94
#
# java.lang.NullPointerException: java.lang.NullPointerException

# %%
#결과
reviews
# Out:
#       Unnamed: 0  Unnamed: 0.1              titles  rates  \
# 0              0             0               미니언즈2     10
# 1              1             1  아이언 크로스: 노르망디 상륙작전     10
# 2              2             2             외계+인 1부     10
# 3              3             3                  메기      1
# 4              4             4              헤어질 결심     10
# ...          ...           ...                 ...    ...
# 9985        9985          9985               씨 비스트     10
# 9986        9986          9986              헤어질 결심     10
# 9987        9987          9987               그레이 맨     10
# 9988        9988          9988             외계+인 1부      8
# 9989        9989          9989             아무도 모른다     10
#
#                                                 reviews isit_domestic
# 0      미니언즈가 귀여운데 알아듣지 못하는 말을 해서 아쉽다. 어린이 조카가 무지 좋아한...         False
# 1                       전투 액션이 좋네요...스케일이 엄청납니다                 False
# 2               호불호가 있다고 했지만 재밌게 봤어요 2부도 기대 됩니다                  True
# 3        편하고 안전하게만 살아온 사람들만 공감할 수 있는 피해 망상의 영화…                  True
# 4                       많은 여운을 남긴 영화, 탕웨이 예뻐요!!                  True
# ...                                                 ...           ...
# 9985          뻔한스토리 전혀 없음 좋은 영화 아끼는 사람들과 함께 보세요                  True
# 9986                    기대 안 하고 봤는데 정말 재미있었습니다.                  True
# 9987   인생 액션영화 리스트에 저장했습니다.2시간 정말지루하지 않고 몰입감 있는 전개는 ...         False
# 9988  신선하고 재밌었어요. 평이 안 좋아서 기대를 안하고 가서 그랬는지 의외로 괜찮더라구...          True
# 9989   엄마가 첫째에게 돈을 남기고 갔을때 아들이 놀라지 않고 돈이 얼마인지 세는 장면이...          True
#
# [9990 rows x 6 columns]
